# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

from time import sleep

# %%
# Lee el archivo CSV
df = pd.read_csv("animal_info.csv")

# %%
nombres = df["name"].unique().tolist()

# %%
nombres
# Out:
# ['Aardvark',
#  'Aardwolf',
#  'Abyssinian',
#  'Addax',
#  'Adelie Penguin',
#  'Aesculapian snake',
#  'Affenpinscher',
#  'Afghan Hound',
#  'African Bullfrog',
#  'African Bush Elephant',
#  'African Civet',
#  'African Clawed Frog',
#  'African Forest Elephant',
#  'African Grey Parrot',
#  'African Palm Civet',
#  'African Penguin',
#  'African Tree Toad',
#  'African Wild Dog',
#  'Agama Lizard',
#  'Aidi',
#  'Ainu',
#  'Airedale Terrier',
#  'Airedoodle',
#  'Akbash',
#  'Akita',
#  'Akita Shepherd',
#  'Alabai',
#  'Alaskan Husky',
#  'Alaskan Klee Kai',
#  'Alaskan Malamute',
#  'Alaskan Shepherd',
#  'Albacore Tuna',
#  'Albatross',
#  'Aldabra Giant Tortoise',
#  'Alligator',
#  'Alligator Gar',
#  'Alpaca',
#  'Alpine Dachsbracke',
#  'Alpine Goat',
#  'Alusky',
#  'Amazon Parrot',
#  'Amazon River Dolphin (Pink Dolphin)',
#  'Ambrosia Beetle',
#  'American Alsatian',
#  'American Bulldog',
#  'American Cocker Spaniel',
#  'American Cockroach',
#  'American Coonhound',
# ...

# %%
chrome_driver = "./chromedriver.exe"
browser = webdriver.Chrome()
browser.get("https://www.google.com/search?q=g&sca_esv=576910264&hl=es&tbm=isch&source=lnms&sa=X&ved=2ahUKEwjYyoSAspSCAxXOU6QEHes1BzYQ_AUoAnoECAEQBA&biw=1366&bih=647&dpr=1")

# %%
browser.find_element(by = By.CSS_SELECTOR, value = "#yDmH0d > c-wiz > div > div > div > div.NIoIEf > div.G4njw > div.AIC7ge > div.CxJub > div.VtwTSb > form:nth-child(2) > div > div > button > span").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\Ane Zubieta\Documents\Proyectos_datascience\Proyecto_animal\Grupal\2.Web_scraping.ipynb Celda 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ane%20Zubieta/Documents/Proyectos_datascience/Proyecto_animal/Grupal/2.Web_scraping.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> browser.find_element(by = By.CSS_SELECTOR, value = "#yDmH0d > c-wiz > div > div > div > div.NIoIEf > div.G4njw > div.AIC7ge > div.CxJub > div.VtwTSb > form:nth-child(2) > div > div > button > span").click()
#
# File c:\Users\Ane Zubieta\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
# ...

# %%
campo_input =  browser.find_element(By.CSS_SELECTOR, '#REsRA')

# %%
campo_input.send_keys("Clase animal Aardwolf")

# %%
browser.find_element(By.CSS_SELECTOR, '#BIqFsb').click()

# %%
soup = BeautifulSoup(browser.page_source, "html.parser")

# %%
filtrado = soup.find_all("img", class_= "rg_i Q4LuWd")

# %%
filtrado
# Out:
# [<img alt="Datos de Lobo de tierra, dieta, hábitat e imágenes en Animalia.bio" class="rg_i Q4LuWd" data-atf="true" data-deferred="1" data-iml="2736.2999999523163" height="180" jsname="Q4LuWd" src="data:image/jpeg;base64,..." width="225"/>,
#  <img alt="Aardwolf Animal Facts | Proteles cristata - AZ Animals" class="rg_i Q4LuWd" data-atf="true" data-deferred="1" data-iml="2927.0999999046326" height="163" jsname="Q4LuWd" src="data:image/jpeg;base64,..." width="311"/>,
#  <img alt="Datos de Lobo de tierra, dieta, hábitat e imágenes en Animalia.bio" class="rg_i Q4LuWd" data-atf="true" data-deferred="1" data-iml="2948.0999999046326" height="180" jsname="Q4LuWd" src="data:image/jpeg;base64,..." width="180"/>,
#  <img alt="Aardwolf | NatureRules1 Wiki | Fandom" class="rg_i Q4LuWd" data-atf="false" data-deferred="1" data-iml="3104.2999999523163" height="181" jsname="Q4LuWd" src="data:image/jpeg;base64,..." width="220"/>,
# ...

# %%
lista = []

# %%
for f in filtrado:
    if "src" in f.attrs:
        print(f["src"])
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...

# %%
lista
# Out:
# ['data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...']

# %%
for e in lista:
    if e.startswith("https"):
        lista.append(e)

# %%
lista
# Out:
# ['data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...']

# %%
for f in filtrado:
    if "src" in f.attrs:
        for e in [f["src"]]:
            if e.startswith("https"):
                print(e.startswith("https"))

# %%
lista[0]
# Out:
# 'data:image/jpeg;base64,...'
